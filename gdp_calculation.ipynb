# %%
from pyspark import SparkConf, SparkContext
import sys
import json
import re
from io import StringIO
import operator
import pandas as pd
import openpyxl
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import udf
from pyspark.sql.types import DoubleType


from pyspark.sql import SparkSession, functions, types,DataFrameReader,DataFrame,DataFrameNaFunctions
from pyspark.sql import *

spark = SparkSession.builder.appName('example code').getOrCreate()

sc = spark.sparkContext


#assert sys.version_info >= (3, 5) # make sure we have Python 3.5+


def main(Final_Exports,Final_Imports,Investment,Government_Expenditure,Consumption,Others):

    final_exports = spark.read.csv(Final_Exports,header=True)
    
    final_exports= final_exports.withColumnRenamed("Country Name","Country_Name")
    final_exports= final_exports.withColumnRenamed("Country Code","Country_Code")
    final_exports= final_exports.withColumn("year_1968", final_exports["1968"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1969", final_exports["1969"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1970", final_exports["1970"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1971", final_exports["1971"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1972", final_exports["1972"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1973", final_exports["1973"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1974", final_exports["1974"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1975", final_exports["1975"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1976", final_exports["1976"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1977", final_exports["1977"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1978", final_exports["1978"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1979", final_exports["1979"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1980", final_exports["1980"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1981", final_exports["1981"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1982", final_exports["1982"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1983", final_exports["1983"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1984", final_exports["1984"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1985", final_exports["1985"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1986", final_exports["1986"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1987", final_exports["1987"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1988", final_exports["1988"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1989", final_exports["1989"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1990", final_exports["1990"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1991", final_exports["1991"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1992", final_exports["1992"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1993", final_exports["1993"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1994", final_exports["1994"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1995", final_exports["1995"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1996", final_exports["1996"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1997", final_exports["1997"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1998", final_exports["1998"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_1999", final_exports["1999"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2000", final_exports["2000"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2001", final_exports["2001"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2002", final_exports["2002"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2003", final_exports["2003"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2004", final_exports["2004"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2005", final_exports["2005"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2006", final_exports["2006"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2007", final_exports["2007"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2008", final_exports["2008"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2009", final_exports["2009"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2010", final_exports["2010"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2011", final_exports["2011"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2012", final_exports["2012"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2013", final_exports["2013"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2014", final_exports["2014"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2015", final_exports["2015"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2016", final_exports["2016"].cast(DoubleType()))
    final_exports= final_exports.withColumn("year_2017", final_exports["2017"].cast(DoubleType()))
   
    final_exports= final_exports.fillna(0)
   
    final_exports.createOrReplaceTempView('final_exports')
    
   
    final_exports=final_exports.drop("1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017")
    
    final_exports.createOrReplaceTempView('final_exports')
    
    
    
    
    
   
    
    
    ###for final_imports
    
    final_imports = spark.read.csv(Final_Imports,header=True)
    
    final_imports = final_imports.withColumnRenamed("Country Name","Country_Name")
    final_imports = final_imports.withColumnRenamed("Country Code","Country_Code")
    final_imports = final_imports.withColumn("year_1968", final_imports["1968"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1969", final_imports["1969"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1970", final_imports["1970"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1971", final_imports["1971"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1972", final_imports["1972"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1973", final_imports["1973"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1974", final_imports["1974"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1975", final_imports["1975"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1976", final_imports["1976"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1977", final_imports["1977"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1978", final_imports["1978"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1979", final_imports["1979"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1980", final_imports["1980"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1981", final_imports["1981"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1982", final_imports["1982"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1983", final_imports["1983"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1984", final_imports["1984"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1985", final_imports["1985"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1986", final_imports["1986"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1987", final_imports["1987"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1988", final_imports["1988"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1989", final_imports["1989"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1990", final_imports["1990"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1991", final_imports["1991"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1992", final_imports["1992"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1993", final_imports["1993"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1994", final_imports["1994"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1995", final_imports["1995"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1996", final_imports["1996"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1997", final_imports["1997"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1998", final_imports["1998"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_1999", final_imports["1999"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2000", final_imports["2000"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2001", final_imports["2001"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2002", final_imports["2002"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2003", final_imports["2003"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2004", final_imports["2004"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2005", final_imports["2005"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2006", final_imports["2006"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2007", final_imports["2007"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2008", final_imports["2008"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2009", final_imports["2009"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2010", final_imports["2010"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2011", final_imports["2011"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2012", final_imports["2012"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2013", final_imports["2013"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2014", final_imports["2014"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2015", final_imports["2015"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2016", final_imports["2016"].cast(DoubleType()))
    final_imports = final_imports.withColumn("year_2017", final_imports["2017"].cast(DoubleType()))
    
    final_imports = final_imports.fillna(0)
    
    final_imports.createOrReplaceTempView('final_imports')
    
    final_imports=final_imports.drop("1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017")
    
    final_imports.createOrReplaceTempView('final_imports')

    
    
    
    
    
    
    
    
    ##For investment
    
    investment= spark.read.csv(Investment,header=True)
    
    investment= investment.withColumnRenamed("Country Name","Country_Name")
    investment= investment.withColumnRenamed("Country Code","Country_Code")
    investment= investment.withColumn("year_1968", investment["1968"].cast(DoubleType()))
    investment= investment.withColumn("year_1969", investment["1969"].cast(DoubleType()))
    investment= investment.withColumn("year_1970", investment["1970"].cast(DoubleType()))
    investment= investment.withColumn("year_1971", investment["1971"].cast(DoubleType()))
    investment= investment.withColumn("year_1972", investment["1972"].cast(DoubleType()))
    investment= investment.withColumn("year_1973", investment["1973"].cast(DoubleType()))
    investment= investment.withColumn("year_1974", investment["1974"].cast(DoubleType()))
    investment= investment.withColumn("year_1975", investment["1975"].cast(DoubleType()))
    investment= investment.withColumn("year_1976", investment["1976"].cast(DoubleType()))
    investment= investment.withColumn("year_1977", investment["1977"].cast(DoubleType()))
    investment= investment.withColumn("year_1978", investment["1978"].cast(DoubleType()))
    investment= investment.withColumn("year_1979", investment["1979"].cast(DoubleType()))
    investment= investment.withColumn("year_1980", investment["1980"].cast(DoubleType()))
    investment= investment.withColumn("year_1981", investment["1981"].cast(DoubleType()))
    investment= investment.withColumn("year_1982", investment["1982"].cast(DoubleType()))
    investment= investment.withColumn("year_1983", investment["1983"].cast(DoubleType()))
    investment= investment.withColumn("year_1984", investment["1984"].cast(DoubleType()))
    investment= investment.withColumn("year_1985", investment["1985"].cast(DoubleType()))
    investment= investment.withColumn("year_1986", investment["1986"].cast(DoubleType()))
    investment= investment.withColumn("year_1987", investment["1987"].cast(DoubleType()))
    investment= investment.withColumn("year_1988", investment["1988"].cast(DoubleType()))
    investment= investment.withColumn("year_1989", investment["1989"].cast(DoubleType()))
    investment= investment.withColumn("year_1990", investment["1990"].cast(DoubleType()))
    investment= investment.withColumn("year_1991", investment["1991"].cast(DoubleType()))
    investment= investment.withColumn("year_1992", investment["1992"].cast(DoubleType()))
    investment= investment.withColumn("year_1993", investment["1993"].cast(DoubleType()))
    investment= investment.withColumn("year_1994", investment["1994"].cast(DoubleType()))
    investment= investment.withColumn("year_1995", investment["1995"].cast(DoubleType()))
    investment= investment.withColumn("year_1996", investment["1996"].cast(DoubleType()))
    investment= investment.withColumn("year_1997", investment["1997"].cast(DoubleType()))
    investment= investment.withColumn("year_1998", investment["1998"].cast(DoubleType()))
    investment= investment.withColumn("year_1999", investment["1999"].cast(DoubleType()))
    investment= investment.withColumn("year_2000", investment["2000"].cast(DoubleType()))
    investment= investment.withColumn("year_2001", investment["2001"].cast(DoubleType()))
    investment= investment.withColumn("year_2002", investment["2002"].cast(DoubleType()))
    investment= investment.withColumn("year_2003", investment["2003"].cast(DoubleType()))
    investment= investment.withColumn("year_2004", investment["2004"].cast(DoubleType()))
    investment= investment.withColumn("year_2005", investment["2005"].cast(DoubleType()))
    investment= investment.withColumn("year_2006", investment["2006"].cast(DoubleType()))
    investment= investment.withColumn("year_2007", investment["2007"].cast(DoubleType()))
    investment= investment.withColumn("year_2008", investment["2008"].cast(DoubleType()))
    investment= investment.withColumn("year_2009", investment["2009"].cast(DoubleType()))
    investment= investment.withColumn("year_2010", investment["2010"].cast(DoubleType()))
    investment= investment.withColumn("year_2011", investment["2011"].cast(DoubleType()))
    investment= investment.withColumn("year_2012", investment["2012"].cast(DoubleType()))
    investment= investment.withColumn("year_2013", investment["2013"].cast(DoubleType()))
    investment= investment.withColumn("year_2014", investment["2014"].cast(DoubleType()))
    investment= investment.withColumn("year_2015", investment["2015"].cast(DoubleType()))
    investment= investment.withColumn("year_2016", investment["2016"].cast(DoubleType()))
    investment= investment.withColumn("year_2017", investment["2017"].cast(DoubleType()))
    
    investment= investment.fillna(0)
    
    investment.createOrReplaceTempView('investment')
    
    investment=investment.drop("1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017")
    
    investment.createOrReplaceTempView('investment')

    
    
    
    
    
    
    
    
    ###FOR GOVERNEMNT EXPENDITURE
    
    
    government_expenditure= spark.read.csv(Government_Expenditure,header=True)
    
    government_expenditure= government_expenditure.withColumnRenamed("Country Name","Country_Name")
    government_expenditure= government_expenditure.withColumnRenamed("Country Code","Country_Code")
    government_expenditure= government_expenditure.withColumn("year_1968", government_expenditure["1968"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1969", government_expenditure["1969"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1970", government_expenditure["1970"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1971", government_expenditure["1971"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1972", government_expenditure["1972"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1973", government_expenditure["1973"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1974", government_expenditure["1974"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1975", government_expenditure["1975"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1976", government_expenditure["1976"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1977", government_expenditure["1977"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1978", government_expenditure["1978"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1979", government_expenditure["1979"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1980", government_expenditure["1980"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1981", government_expenditure["1981"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1982", government_expenditure["1982"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1983", government_expenditure["1983"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1984", government_expenditure["1984"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1985", government_expenditure["1985"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1986", government_expenditure["1986"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1987", government_expenditure["1987"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1988", government_expenditure["1988"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1989", government_expenditure["1989"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1990", government_expenditure["1990"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1991", government_expenditure["1991"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1992", government_expenditure["1992"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1993", government_expenditure["1993"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1994", government_expenditure["1994"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1995", government_expenditure["1995"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1996", government_expenditure["1996"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1997", government_expenditure["1997"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1998", government_expenditure["1998"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_1999", government_expenditure["1999"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2000", government_expenditure["2000"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2001", government_expenditure["2001"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2002", government_expenditure["2002"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2003", government_expenditure["2003"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2004", government_expenditure["2004"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2005", government_expenditure["2005"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2006", government_expenditure["2006"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2007", government_expenditure["2007"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2008", government_expenditure["2008"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2009", government_expenditure["2009"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2010", government_expenditure["2010"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2011", government_expenditure["2011"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2012", government_expenditure["2012"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2013", government_expenditure["2013"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2014", government_expenditure["2014"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2015", government_expenditure["2015"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2016", government_expenditure["2016"].cast(DoubleType()))
    government_expenditure= government_expenditure.withColumn("year_2017", government_expenditure["2017"].cast(DoubleType()))
    
    government_expenditure= government_expenditure.fillna(0)
    
    government_expenditure.createOrReplaceTempView('government_expenditure')
    
    government_expenditure=government_expenditure.drop("1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017")
    
    government_expenditure.createOrReplaceTempView('government_expenditure')


    
    
    
    
    
    
       
    ###FOR Consumption
    
    
    consumption= spark.read.csv(Consumption,header=True)
    
    consumption= consumption.withColumnRenamed("Country Name","Country_Name")
    consumption= consumption.withColumnRenamed("Country Code","Country_Code")
    consumption= consumption.withColumn("year_1968", consumption["1968"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1969", consumption["1969"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1970", consumption["1970"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1971", consumption["1971"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1972", consumption["1972"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1973", consumption["1973"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1974", consumption["1974"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1975", consumption["1975"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1976", consumption["1976"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1977", consumption["1977"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1978", consumption["1978"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1979", consumption["1979"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1980", consumption["1980"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1981", consumption["1981"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1982", consumption["1982"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1983", consumption["1983"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1984", consumption["1984"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1985", consumption["1985"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1986", consumption["1986"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1987", consumption["1987"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1988", consumption["1988"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1989", consumption["1989"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1990", consumption["1990"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1991", consumption["1991"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1992", consumption["1992"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1993", consumption["1993"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1994", consumption["1994"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1995", consumption["1995"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1996", consumption["1996"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1997", consumption["1997"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1998", consumption["1998"].cast(DoubleType()))
    consumption= consumption.withColumn("year_1999", consumption["1999"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2000", consumption["2000"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2001", consumption["2001"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2002", consumption["2002"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2003", consumption["2003"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2004", consumption["2004"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2005", consumption["2005"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2006", consumption["2006"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2007", consumption["2007"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2008", consumption["2008"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2009", consumption["2009"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2010", consumption["2010"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2011", consumption["2011"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2012", consumption["2012"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2013", consumption["2013"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2014", consumption["2014"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2015", consumption["2015"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2016", consumption["2016"].cast(DoubleType()))
    consumption= consumption.withColumn("year_2017", consumption["2017"].cast(DoubleType()))
    
    consumption= consumption.fillna(0)
    
    consumption.createOrReplaceTempView('consumption')
    
    consumption=consumption.drop("1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017")
    
    consumption.createOrReplaceTempView('consumption')


    
    
    
    
    ###FOR Others
    
    
    others= spark.read.csv(Others,header=True)
    
    others= others.withColumnRenamed("Country Name","Country_Name")
    others= others.withColumnRenamed("Country Code","Country_Code")
    others= others.withColumn("year_1968", others["1968"].cast(DoubleType()))
    others= others.withColumn("year_1969", others["1969"].cast(DoubleType()))
    others= others.withColumn("year_1970", others["1970"].cast(DoubleType()))
    others= others.withColumn("year_1971", others["1971"].cast(DoubleType()))
    others= others.withColumn("year_1972", others["1972"].cast(DoubleType()))
    others= others.withColumn("year_1973", others["1973"].cast(DoubleType()))
    others= others.withColumn("year_1974", others["1974"].cast(DoubleType()))
    others= others.withColumn("year_1975", others["1975"].cast(DoubleType()))
    others= others.withColumn("year_1976", others["1976"].cast(DoubleType()))
    others= others.withColumn("year_1977", others["1977"].cast(DoubleType()))
    others= others.withColumn("year_1978", others["1978"].cast(DoubleType()))
    others= others.withColumn("year_1979", others["1979"].cast(DoubleType()))
    others= others.withColumn("year_1980", others["1980"].cast(DoubleType()))
    others= others.withColumn("year_1981", others["1981"].cast(DoubleType()))
    others= others.withColumn("year_1982", others["1982"].cast(DoubleType()))
    others= others.withColumn("year_1983", others["1983"].cast(DoubleType()))
    others= others.withColumn("year_1984", others["1984"].cast(DoubleType()))
    others= others.withColumn("year_1985", others["1985"].cast(DoubleType()))
    others= others.withColumn("year_1986", others["1986"].cast(DoubleType()))
    others= others.withColumn("year_1987", others["1987"].cast(DoubleType()))
    others= others.withColumn("year_1988", others["1988"].cast(DoubleType()))
    others= others.withColumn("year_1989", others["1989"].cast(DoubleType()))
    others= others.withColumn("year_1990", others["1990"].cast(DoubleType()))
    others= others.withColumn("year_1991", others["1991"].cast(DoubleType()))
    others= others.withColumn("year_1992", others["1992"].cast(DoubleType()))
    others= others.withColumn("year_1993", others["1993"].cast(DoubleType()))
    others= others.withColumn("year_1994", others["1994"].cast(DoubleType()))
    others= others.withColumn("year_1995", others["1995"].cast(DoubleType()))
    others= others.withColumn("year_1996", others["1996"].cast(DoubleType()))
    others= others.withColumn("year_1997", others["1997"].cast(DoubleType()))
    others= others.withColumn("year_1998", others["1998"].cast(DoubleType()))
    others= others.withColumn("year_1999", others["1999"].cast(DoubleType()))
    others= others.withColumn("year_2000", others["2000"].cast(DoubleType()))
    others= others.withColumn("year_2001", others["2001"].cast(DoubleType()))
    others= others.withColumn("year_2002", others["2002"].cast(DoubleType()))
    others= others.withColumn("year_2003", others["2003"].cast(DoubleType()))
    others= others.withColumn("year_2004", others["2004"].cast(DoubleType()))
    others= others.withColumn("year_2005", others["2005"].cast(DoubleType()))
    others= others.withColumn("year_2006", others["2006"].cast(DoubleType()))
    others= others.withColumn("year_2007", others["2007"].cast(DoubleType()))
    others= others.withColumn("year_2008", others["2008"].cast(DoubleType()))
    others= others.withColumn("year_2009", others["2009"].cast(DoubleType()))
    others= others.withColumn("year_2010", others["2010"].cast(DoubleType()))
    others= others.withColumn("year_2011", others["2011"].cast(DoubleType()))
    others= others.withColumn("year_2012", others["2012"].cast(DoubleType()))
    others= others.withColumn("year_2013", others["2013"].cast(DoubleType()))
    others= others.withColumn("year_2014", others["2014"].cast(DoubleType()))
    others= others.withColumn("year_2015", others["2015"].cast(DoubleType()))
    others= others.withColumn("year_2016", others["2016"].cast(DoubleType()))
    others= others.withColumn("year_2017", others["2017"].cast(DoubleType()))
    
    others= others.fillna(0)
    
    others.createOrReplaceTempView('others')
    
    others=others.drop("1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017")
    
    others.createOrReplaceTempView('others')


    
    
    
    
   
    
    gdp=spark.sql("select f_e.Country_Name,f_e.Country_Code,\
    (f_e.year_1968-f_i.year_1968 + i.year_1968+g_e.year_1968+ c.year_1968+ o.year_1968) as year_1968, \
    (f_e.year_1969-f_i.year_1969 + i.year_1969+ g_e.year_1969+ c.year_1969+ o.year_1969) as year_1969,\
    (f_e.year_1970-f_i.year_1970 + i.year_1970+g_e.year_1970+ c.year_1970+ o.year_1970) as year_1970,\
    (f_e.year_1971-f_i.year_1971 + i.year_1971+g_e.year_1971+ c.year_1971+ o.year_1971) as year_1971,\
    (f_e.year_1972-f_i.year_1972 + i.year_1972+g_e.year_1972+ c.year_1972+ o.year_1972) as year_1972,\
    (f_e.year_1973-f_i.year_1973 + i.year_1973+g_e.year_1973+ c.year_1973+ o.year_1973) as year_1973,\
    (f_e.year_1974-f_i.year_1974 + i.year_1974+g_e.year_1974+ c.year_1974+ o.year_1974) as year_1974,\
    (f_e.year_1975-f_i.year_1975 + i.year_1975+g_e.year_1975+ c.year_1975+ o.year_1975) as year_1975,\
    (f_e.year_1976-f_i.year_1976 + i.year_1976+g_e.year_1975+ c.year_1976+ o.year_1976) as year_1976,\
    (f_e.year_1977-f_i.year_1977 + i.year_1977+g_e.year_1977+ c.year_1977+ o.year_1977) as year_1977,\
    (f_e.year_1978-f_i.year_1978 + i.year_1978+g_e.year_1978+ c.year_1978+ o.year_1978) as year_1978,\
    (f_e.year_1979-f_i.year_1979 + i.year_1979+g_e.year_1979+ c.year_1979+ o.year_1979) as year_1979,\
    (f_e.year_1980-f_i.year_1980 + i.year_1980+g_e.year_1980+ c.year_1980+ o.year_1980) as year_1980,\
    (f_e.year_1981-f_i.year_1981 + i.year_1981+g_e.year_1981+ c.year_1981+ o.year_1981) as year_1981,\
    (f_e.year_1982-f_i.year_1982 + i.year_1982+g_e.year_1982+ c.year_1982+ o.year_1982) as year_1982,\
    (f_e.year_1983-f_i.year_1983 + i.year_1983+g_e.year_1983+ c.year_1983+ o.year_1983) as year_1983,\
    (f_e.year_1984-f_i.year_1984 + i.year_1984+g_e.year_1984+ c.year_1984+ o.year_1984) as year_1984,\
    (f_e.year_1985-f_i.year_1985 + i.year_1985+g_e.year_1985+ c.year_1985+ o.year_1985) as year_1985,\
    (f_e.year_1986-f_i.year_1986 + i.year_1986+g_e.year_1986+ c.year_1986+ o.year_1986) as year_1986,\
    (f_e.year_1987-f_i.year_1987 + i.year_1987+g_e.year_1987+ c.year_1987+ o.year_1987) as year_1987,\
    (f_e.year_1988-f_i.year_1988 + i.year_1988+g_e.year_1988+ c.year_1988+ o.year_1988) as year_1988,\
    (f_e.year_1989-f_i.year_1989 + i.year_1989+g_e.year_1989+ c.year_1989+ o.year_1989) as year_1989,\
    (f_e.year_1990-f_i.year_1990 + i.year_1990+g_e.year_1990+ c.year_1990+ o.year_1990) as year_1990,\
    (f_e.year_1991-f_i.year_1991 + i.year_1991+g_e.year_1991+ c.year_1991+ o.year_1991) as year_1991,\
    (f_e.year_1992-f_i.year_1992 + i.year_1992+g_e.year_1992+ c.year_1992+ o.year_1992) as year_1992,\
    (f_e.year_1993-f_i.year_1993 + i.year_1993+g_e.year_1993+ c.year_1993+ o.year_1993) as year_1993,\
    (f_e.year_1994-f_i.year_1994 + i.year_1994+g_e.year_1994+ c.year_1994+ o.year_1994) as year_1994,\
    (f_e.year_1995-f_i.year_1995 + i.year_1995+g_e.year_1995+ c.year_1995+ o.year_1995) as year_1995,\
    (f_e.year_1996-f_i.year_1996 + i.year_1996+g_e.year_1996+ c.year_1996+ o.year_1996) as year_1996,\
    (f_e.year_1997-f_i.year_1997 + i.year_1997+g_e.year_1997+ c.year_1997+ o.year_1997) as year_1997,\
    (f_e.year_1998-f_i.year_1998 + i.year_1998+g_e.year_1998+ c.year_1998+ o.year_1998) as year_1998,\
    (f_e.year_1999-f_i.year_1999 + i.year_1999+g_e.year_1999+ c.year_1999+ o.year_1999) as year_1999,\
    (f_e.year_2000-f_i.year_2000 + i.year_2000+g_e.year_2000+ c.year_2000+ o.year_2000) as year_2000,\
    (f_e.year_2001-f_i.year_2001 + i.year_2001+g_e.year_2001+ c.year_2001+ o.year_2001) as year_2001,\
    (f_e.year_2002-f_i.year_2002 + i.year_2002+g_e.year_2002+ c.year_2002+ o.year_2002) as year_2002,\
    (f_e.year_2003-f_i.year_2003 + i.year_2003+g_e.year_2003+ c.year_2003+ o.year_2003) as year_2003,\
    (f_e.year_2004-f_i.year_2004 + i.year_2004+g_e.year_2004+ c.year_2004+ o.year_2004) as year_2004,\
    (f_e.year_2005-f_i.year_2005 + i.year_2005+g_e.year_2005+ c.year_2005+ o.year_2005) as year_2005,\
    (f_e.year_2006-f_i.year_2006 + i.year_2006+g_e.year_2006+ c.year_2006+ o.year_2006) as year_2006,\
    (f_e.year_2007-f_i.year_2007 + i.year_2007+g_e.year_2007+ c.year_2007+ o.year_2007) as year_2007,\
    (f_e.year_2008-f_i.year_2008 + i.year_2008+g_e.year_2008+ c.year_2008+ o.year_2008) as year_2008,\
    (f_e.year_2009-f_i.year_2009 + i.year_2009+g_e.year_2009+ c.year_2009+ o.year_2009) as year_2009,\
    (f_e.year_2010-f_i.year_2010 + i.year_2010+g_e.year_2010+ c.year_2010+ o.year_2010) as year_2010,\
    (f_e.year_2011-f_i.year_2011 + i.year_2011+g_e.year_2011+ c.year_2011+ o.year_2011) as year_2011,\
    (f_e.year_2012-f_i.year_2012 + i.year_2012+g_e.year_2012+ c.year_2012+ o.year_2012) as year_2012,\
    (f_e.year_2013-f_i.year_2013 + i.year_2013+g_e.year_2013+ c.year_2013+ o.year_2013) as year_2013,\
    (f_e.year_2014-f_i.year_2014 + i.year_2014+g_e.year_2014+ c.year_2014+ o.year_2014) as year_2014,\
    (f_e.year_2015-f_i.year_2015 + i.year_2015+g_e.year_2015+ c.year_2015+ o.year_2015) as year_2015,\
    (f_e.year_2016-f_i.year_2016 + i.year_2016+g_e.year_2016+ c.year_2016+ o.year_2016) as year_2016,\
    (f_e.year_2017-f_i.year_2017 + i.year_2017+g_e.year_2017+ c.year_2017+ o.year_2017) as year_2017\
    from final_exports f_e join final_imports f_i on f_e.Country_Name=f_i.Country_Name \
    join investment i on i.Country_Name=f_e.Country_Name \
    join government_expenditure g_e on g_e.Country_Name=f_e.Country_Name \
    join consumption c on c.Country_Name=f_e.Country_Name \
    join others o on o.Country_Name=f_e.Country_Name order by f_i.Country_Name")

    

    
    

    
    
    df = pd.DataFrame(gdp.take(300), columns=gdp.columns)


    df.to_csv('/Users/mananparasher/Documents/big_data_project/gdp/check5.csv')
   
   
    
    
if __name__ == '__main__':
    Final_Exports = "/Users/mananparasher/Documents/big_data_project/gdp/Final_Exports.csv"
    Final_Imports = "/Users/mananparasher/Documents/big_data_project/gdp/Final_Imports.csv"
    Investment = "/Users/mananparasher/Documents/big_data_project/gdp/Investment.csv"
    Government_Expenditure = "/Users/mananparasher/Documents/big_data_project/gdp/Government_Expenditure.csv"
    Consumption = "/Users/mananparasher/Documents/big_data_project/gdp/Consumption.csv"
    Others = "/Users/mananparasher/Documents/big_data_project/gdp/Others.csv"
    main(Final_Exports,Final_Imports,Investment,Government_Expenditure,Consumption,Others)
